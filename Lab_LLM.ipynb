# %%
# !pip -q install transformers einops accelerate
# Out:
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import AutoTokenizer
import transformers

# %%
model = "TinyLlama/TinyLlama_v1.1"
tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# c:\Users\chama\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\chama\.cache\huggingface\hub\models--TinyLlama--TinyLlama_v1.1. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/560 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/4.40G [00:00<?, ?B/s]
# Error while downloading from https://cdn-lfs-us-1.hf.co/repos/10/61/10612fdf3ee9613113fea71958fdc977de490b3138be32c98d470ff09f790655/9da94323c2813359fed660ec4aa71684488423c46d5317b7dc9f430738abf0d5?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27pytorch_model.bin%3B+filename%3D%22pytorch_model.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1729989624&Policy=...&Signature=J6SgF-GWKSOXGJ1f8YamztnyykIDXM7ctJq4eMZbNefg8HTpJbPiq2f6Ty4FS-2uYon2Y%7E983GaNIRIK2bDkqsG6Kk-jrnj0mcdF1HT8cseQ4l8hntoG-4QRaMFHICV847lbc86ga3omprpODhja9MsNm748ONN%7EBAyKOS6VMIBY8fdIIEBq9UTzISD9DgO8P8ethmLpdQTrtPpFylReXu2AodVYMxl67VRoSil%7EX8EuihXTAIvUao-fpj93vRsjWVFwWlWuMaiFKUbztVatQJau3vm%7ETR6Ga9PTnmnJbzfiUiYq%7Eusk8mS0BcoFx9DsESV7K5b6N-7OO0J8gx0u%7EQ__&Key-Pair-Id=K24J24Z295AEI9: HTTPSConnectionPool(host='cdn-lfs-us-1.hf.co', port=443): Read timed out.
# Trying to resume download...
# pytorch_model.bin:  21%|##        | 923M/4.40G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/129 [00:00<?, ?B/s]

# %%
prompt = "Explain to me the difference between nuclear fission and fusion."
response = pipeline(
    prompt,
    max_length=500,
    truncation = True,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
print(response[0]['generated_text'])
# Out:
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Explain to me the difference between nuclear fission and fusion.
# In fact, the most successful way is to use a mixture of both. It is called a "hybrid" (and it's also an example of "synergism").
# It may be possible to use both a mix of "high-tech" and "high-touch" (human touch) approaches, depending on your particular situation.
# I think that the best way to describe this is "synergy".
# Synergy is the combination of two or more resources to get results that were not possible to accomplish separately. Synergy has been used by engineers and others to describe a variety of situations where a combination of two or more resources (such as two types of machines used together) creates more powerful results than the sum of their parts.
# I think that the best way to describe this is "synergy". The two approaches to the problem are called "high technology" and "high contact".
# High technology is an attempt to make the process faster. High touch is an attempt to make the process more personal and more satisfying to the customer.
# The goal is to get a high-value product to the customers as rapidly as possible, in the best possible way.
# There are several ways that this can be accomplished.
# One option is to have a team of people who are "high-tech" – engineers, computer scientists, scientists, etc. These people have specialized in making the "high technology" parts of the process fast.
# Another way is to hire people who are "high-touch" – people who are "high-contact." They spend a lot of time getting to know their customers, and listening to their ideas.
# It may be possible to combine both approaches in the most productive way.
# The best way to combine "high-tech" and "high-touch" is to have a hybrid approach. The hybrid approach combines both types of people.
# The hybrid approach combines high-tech people who have specialized in making the "high technology" parts of the process fast, with high-contact people who spend a lot of time getting to know their customers and listening to their ideas.
# This approach may be used to create high-tech parts of the process, and high-contact parts of the process, in a way that is most effective and efficient.
# It

# %%
model = "Doctor-Shotgun/TinyLlama-1.1B-32k-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)
# Out:
# model.safetensors:   6%|6         | 136M/2.20G [00:00<?, ?B/s]
# Error while downloading from https://cdn-lfs-us-1.hf.co/repos/43/08/430837eab9c84acf12a82ff8c5e1d782e474b837a78bbffefb021a9e4c525116/4d50d3a5a6b9cbdd551e334b146ea542d569814b43f6366b036f94522ab39751?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27model.safetensors%3B+filename%3D%22model.safetensors%22%3B&Expires=1729993219&Policy=&Signature=J4d%7Emz3eObI2vYMf2DT1aVGWpe-gzSDPVfxVjr641O7-6aAN3QeRhBHSjOH51JSrqNNfY%7E6enZsJERU1p%7EqgUzU34B1zlUwUX8Dz1YfJrOnliAudqLpsy7SrWq1BQtTt2itrB-kk7okyY8ATYqZ-qq4UN8-pNcMEi4r9KBBogoSdzYtcFYw9k4kHmxZDV3-XXVKTqENI96eAe7VcfveOuZmKSmLKCeyiQ-P7lkVGlBVt06fIyIPnscBvSkKkJMyuCMv5iFztIXpisAAzb2IMavJzoeItvrRy8%7ED3SR53t4EY5BGKsOZFy%7EoEcTo%7Eb32v1kyLEKwfUtOnH4LCN-qI8A__&Key-Pair-Id=K24J24Z295AEI9: HTTPSConnectionPool(host='cdn-lfs-us-1.hf.co', port=443): Read timed out.
# Trying to resume download...
# model.safetensors:  76%|#######5  | 1.67G/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/129 [00:00<?, ?B/s]

# %%
prompt = "Explain to me the difference between nuclear fission and fusion."
response = pipeline(
    prompt,
    max_length=500,
    truncation = True,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
print(response[0]['generated_text'])
# Out:
# Explain to me the difference between nuclear fission and fusion.
# I think that the key difference is that fission is a type of nuclear energy production (the splitting of an atom) and fusion is a type of chemical energy production. Both of these processes are used to make nuclear power, but the key difference lies in the energy released.
# Fission produces energy in the form of a nuclear chain reaction, while fusion releases energy in the form of a chemical reaction. The difference lies in the way these energy outputs are created:

# %%
model = "Maykeye/TinyLLama-v0"
tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/649 [00:00<?, ?B/s]
# c:\Users\chama\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\chama\.cache\huggingface\hub\models--Maykeye--TinyLLama-v0. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer.model:   0%|          | 0.00/534k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.98M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama_fast.LlamaTokenizerFast'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message.
# config.json:   0%|          | 0.00/498 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/9.25M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %%
prompt = "Explain to me the difference between nuclear fission and fusion."
response = pipeline(
    prompt,
    max_length=500,
    truncation = True,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
print(response[0]['generated_text'])
# Out:
# Explain to me the difference between nuclear fission and fusion. She had been able to find something else for a long time and he was very excited that he wanted to go.
# When he came to school, he saw that the other kids were scared and wanted to see what was happening in the park. His little mommy said, "No, I am very scared. Maybe it's a surprise. It's not safe."
# The family looked at them and asked, "Why are you sad?"
# The friends said, "I'm so angry! You need to be more careful and ask for help."
# The other animals agreed to help. They went to her house and said, "We want to try the new food, but we must be careful when we have to be careful."
